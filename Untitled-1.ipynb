# %%
import numpy as np
import matplotlib as mtp
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import math
import sys
from scipy.stats import norm
from scipy.stats import chi2
from matplotlib.ticker import FormatStrFormatter
from scipy import stats
from scipy.constants import g
from matplotlib.ticker import ScalarFormatter
from matplotlib.ticker import StrMethodFormatter
from uncertainties import ufloat
from uncertainties import unumpy as unp
from uncertainties.umath import sqrt
from uncertainties import ufloat

# %%
df=pd.read_excel('Urti.xlsx', sheet_name=0)
df=df.fillna('')
df
# Out:
#             Unnamed: 0         Interpolazione carrello Unnamed: 2  \
# 0                                                    m         sm
# 1                    1                           0.249      0.026
# 2                    2                           0.253      0.034
# 3                    3                           0.247      0.039
# 4                Media                        0.249667
# 5           Incertezza                        0.003055
# 6   Errore sulla media                        0.001764
# 7                        Interpolazione carrello+masse
# 8                                                    m         sm
# 9                    1                           0.769      0.055
# 10                   2                           0.755      0.048
# 11                   3                           0.749      0.051
# 12               Media                        0.757667
# 13          Incertezza                        0.010263
# ...

# %%
m1_interpolata=ufloat(df.iloc[4, 1], df.iloc[6, 1])
m1_misurata=ufloat(df.iloc[0, 5], df.iloc[0, 11])
m2_interpolata=ufloat(df.iloc[12, 1], df.iloc[14, 1])
m2_misurata=ufloat(df.iloc[0, 8], df.iloc[0, 11])
m3_interpolata=ufloat(df.iloc[20, 1], df.iloc[22, 1])
t_test(m1_interpolata, m1_misurata);
t_test(m2_interpolata, m2_misurata);
t_test(m3_interpolata, m1_misurata);
